# %%
import pandas as pd
from pathlib import Path
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
counties = pd.read_csv('counties_list.csv')
counties_list = []
for county in counties['0']:
    x = str(county)
    counties_list.append(x)

# %%
files = []
for i, county in enumerate(counties_list):
    for year in range(2010, 2016):
        fn = f'{county}-{year}.pkl'
        files.append(fn)

concat_df = pd.concat([pd.read_pickle(fp) for fp in files], ignore_index=True)

# %%
concat_df

concat_df.to_pickle('dww_scraper_export')

# %%
names = np.unique(concat_df['Analyte Name'])

# %%
names
# Out:
# array(['1,1,1,2-TETRACHLOROETHANE               ',
#        '1,1,1-TRICHLOROETHANE                   ',
#        '1,1,2,2-TETRACHLOROETHANE               ',
#        '1,1,2-TRICHLOROETHANE                   ',
#        '1,1-DICHLOROETHANE                      ',
#        '1,1-DICHLOROETHYLENE                    ',
#        '1,1-DICHLOROPROPENE                     ',
#        '1,2,3-TRICHLOROBENZENE                  ',
#        '1,2,3-TRICHLOROPROPANE                  ',
#        '1,2,4-TRICHLOROBENZENE                  ',
#        '1,2,4-TRIMETHYLBENZENE                  ',
#        '1,2-DIBROMO-3-CHLOROPROPANE',
#        '1,2-DICHLOROETHANE                      ',
#        '1,2-DICHLOROPROPANE                     ',
#        '1,3,5-TRIMETHYLBENZENE                  ',
#        '1,3-DICHLOROPROPANE                     ', '1,3-DICHLOROPROPENE',
#        '2,2-DICHLOROPROPANE                     ', '2,4,5-TP',
#        '2,4-D                                   ',
#        '3-HYDROXYCARBOFURAN                     ', '38-STRONTIUM-90',
#        'ACIDITY, TOTAL (CACO3)                  ',
#        'ALDICARB                                ',
#        'ALDICARB SULFONE                        ',
#        'ALDICARB SULFOXIDE                      ',
#        'ALDRIN                                  ',
#        'ALKALINITY, TOTAL                       ', 'ALPHA-CHLORDANE',
#        'ANTIMONY, TOTAL                         ',
#        'ARSENIC                                 ',
#        'ASBESTOS                                ',
#        'ATRAZINE                                ',
#        'BARIUM                                  ',
#        'BENZENE                                 ',
#        'BENZO(A)PYRENE                          ',
#        'BERYLLIUM, TOTAL                        ', 'BHC-GAMMA',
#        'BROMATE                                 ',
#        'BROMIDE                                 ',
#        'BROMOBENZENE                            ',
#        'BROMOCHLOROMETHANE                      ',
#        'BROMODICHLOROMETHANE                    ',
#        'BROMOFORM                               ',
#        'BROMOMETHANE                            ',
#        'BUTACHLOR                               ',
#        'CADMIUM                                 ',
#        'CALCIUM                                 ',
#        'CARBARYL                                ',
#        'CARBOFURAN                              ',
#        'CARBON TETRACHLORIDE                    ',
#        'CARBON, DISSOLVED ORGANIC (DOC)         ', 'CARBON, TOTAL',
#        'CHLORDANE                               ',
#        'CHLORIDE                                ',
#        'CHLORITE                                ', 'CHLOROBENZENE',
#        'CHLOROETHANE                            ',
#        'CHLOROFORM                              ',
#        'CHLOROMETHANE                           ',
#        'CHROMIUM                                ',
#        'CIS-1,2-DICHLOROETHYLENE                ',
#        'COLIFORM (TCR)                          ',
#        'COLOR                                   ',
#        'COMBINED RADIUM (-226 & -228)', 'COMBINED URANIUM',
#        'CONDUCTIVITY @ 25 C UMHOS/CM', 'COPPER, FREE',
#        'CYANIDE                                 ',
#        'DALAPON                                 ',
#        'DI(2-ETHYLHEXYL) ADIPATE                ',
#        'DI(2-ETHYLHEXYL) PHTHALATE              ',
#        'DIBROMOACETIC ACID                      ',
#        'DIBROMOCHLOROMETHANE                    ',
#        'DIBROMOMETHANE                          ',
#        'DICAMBA                                 ',
#        'DICHLOROACETIC ACID                     ',
#        'DICHLORODIFLUOROMETHANE                 ', 'DICHLOROMETHANE',
#        'DIELDRIN                                ',
#        'DINOSEB                                 ', 'E. COLI',
#        'ENDRIN                                  ',
#        'ETHYLBENZENE                            ', 'ETHYLENE DIBROMIDE',
#        'FECAL COLIFORM                          ',
#        'FLUORIDE                                ', 'GAMMA-CHLORDANE',
#        'GROSS ALPHA, EXCL. RADON & U            ',
#        'GROSS ALPHA, INCL. RADON & U            ',
#        'GROSS BETA PARTICLE ACTIVITY            ',
#        'HARDNESS, TOTAL (AS CACO3)',
#        'HEPTACHLOR                              ',
#        'HEPTACHLOR EPOXIDE                      ',
#        'HETEROTROPHIC BACTERIA (HPC OR SPC)     ', 'HEXACHLOROBENZENE',
#        'HEXACHLOROBUTADIENE                     ',
#        'HEXACHLOROCYCLOPENTADIENE               ',
#        'IRON                                    ',
#        'ISOPROPYLBENZENE                        ', 'LASSO',
#        'LEAD                                    ',
#        'M-DICHLOROBENZENE                       ',
#        'MAGNESIUM                               ',
#        'MANGANESE                               ',
#        'MERCURY                                 ',
#        'METHOMYL                                ',
#        'METHOXYCHLOR                            ',
#        'METOLACHLOR                             ', 'METRIBUZIN',
#        'MONOBROMOACETIC ACID                    ',
#        'MONOCHLOROACETIC ACID                   ',
#        'N-BUTYLBENZENE                          ',
#        'N-PROPYLBENZENE                         ',
#        'NAPHTHALENE                             ',
#        'NICKEL                                  ',
#        'NITRATE                                 ',
#        'NITRATE-NITRITE                         ',
#        'NITRITE                                 ',
#        'O-CHLOROTOLUENE                         ',
#        'O-DICHLOROBENZENE                       ',
#        'ORTHOPHOSPHATE                          ', 'OXAMYL',
#        'P-CHLOROTOLUENE                         ',
#        'P-DICHLOROBENZENE                       ',
#        'P-ISOPROPYLTOLUENE                      ',
#        'PENTACHLOROPHENOL                       ',
#        'PH                                      ',
#        'PICLORAM                                ',
#        'POTASSIUM-40, TOTAL                     ',
#        'PROPACHLOR                              ',
#        'RADIUM-226                              ',
#        'RADIUM-228                              ',
#        'RADON                                   ',
#        'SEC-BUTYLBENZENE                        ',
#        'SELENIUM                                ',
#        'SILICA                                  ',
#        'SILVER                                  ',
#        'SIMAZINE                                ',
#        'SODIUM                                  ',
#        'STYRENE                                 ',
#        'SULFATE                                 ', 'TDS',
#        'TEMPERATURE (CENTIGRADE)                ',
#        'TERT-BUTYLBENZENE                       ',
#        'TETRACHLOROETHYLENE                     ',
#        'THALLIUM, TOTAL                         ',
#        'TOLUENE                                 ',
#        'TOTAL HALOACETIC ACIDS (HAA5)           ',
#        'TOTAL POLYCHLORINATED BIPHENYLS (PCB)',
#        'TOXAPHENE                               ',
#        'TRANS-1,2-DICHLOROETHYLENE              ',
#        'TRICHLOROACETIC ACID                    ',
#        'TRICHLOROETHYLENE                       ',
#        'TRICHLOROFLUOROMETHANE                  ',
#        'TRITIUM                                 ',
#        'TTHM                                    ',
#        'TURBIDITY                               ',
#        'UV ABSORBANCE @254 NM                   ',
#        'VINYL CHLORIDE                          ',
#        'XYLENES, TOTAL                          ',
#        'ZINC                                    '], dtype=object)

# %%
x = concat_df['Analyte Name'].value_counts()
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 12
fig_size[1] = 70
plt.rcParams["figure.figsize"] = fig_size

plot = plt.barh(x.keys(), x)

# %%
plot
# Out:
# <BarContainer object of 162 artists>

# %%
concat_df.head()
# Out:
#   Analyte Code                              Analyte Name Collection Date  \
# 0         1927  ALKALINITY, TOTAL                             07-22-2010
# 1         2920                             CARBON, TOTAL      07-22-2010
# 2         1038  NITRATE-NITRITE                               04-27-2010
# 3         1040  NITRATE                                       04-27-2010
# 4         1041  NITRITE                                       04-27-2010
#
#           Concentration level Federal Type Lab Sample No. Less than Indicator  \
# 0  36.0             MG/L              C       ET-S-072210                   N
# 1  7.1              MG/L              C       ET-S-072210                   N
# 2  0                                  NC       C004869-02                   Y
# 3                                     NC       C004869-02                   Y
# 4                                     NC       C004869-02                   Y
#
#   Level Type                     Method Code  \
# 0        MDL  2320B
# 1        MDL                            null
# 2        MDL                            null
# 3        MDL  4500NO3-F
# 4        MDL  4500NO3-F
#
#                         Monitoring Period Begin Date  \
# 0  \n\r\n      \r\n\t     07-01-2010\r\n      \r\...
# 1  \n\r\n      \r\n\t     07-01-2010\r\n      \r\...
# 2                                             \n\n\n
# 3  \n\r\n      \r\n\t     01-01-2010\r\n      \r\...
# 4                                             \n\n\n
#
#                           Monitoring Period End Date Principal County Served  \
# 0  \n\r\n      \r\n\t      07-31-2010\r\n      \r...                ALAMANCE
# 1  \n\r\n      \r\n\t      07-31-2010\r\n      \r...                ALAMANCE
# 2                                             \n\n\n                ALAMANCE
# 3  \n\r\n      \r\n\t      12-31-2010\r\n      \r...                ALAMANCE
# 4                                             \n\n\n                ALAMANCE
#
#   Reporting Level       Water System Name Water System No.
# 0     1 MG/L          BURLINGTON, CITY OF     NC0201010
# 1     1 MG/L          BURLINGTON, CITY OF     NC0201010
# 2     1 MG/L       HIDDEN LAKE CAMPGROUND     NC0201187
# 3     1 MG/L       HIDDEN LAKE CAMPGROUND     NC0201187
# 4    .1 MG/L       HIDDEN LAKE CAMPGROUND     NC0201187
